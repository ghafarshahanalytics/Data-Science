# %%
# Import dependencies and required magics
# Importing TextBlob
from textblob import TextBlob
import requests
from bs4 import BeautifulSoup
import numpy as np 
import pandas as pd 
import re
import plotly.express as px


# DOWNLOAD NLTK USING THIS SCRIPT HERE: nltk.download()
# nltk.download()
import nltk
import spacy

#Learn more about SpaCY: https://spacy.io/

# RUN THE 3 SCRIPTS BELOW IN YOUR COMMAND PROMPT TO USE SPACY FOR TEXT ANALYSIS
# 1) pip install -U spacy
# 2) python -m spacy download en_core_web_sm
# 3) python -m spacy download en
nlp = spacy.load('en_core_web_sm')

# %%
df = pd.read_csv("link to file", encoding='utf8')

df
# Out:
#                                                  reviewId          userName  \
# 0       gp:AOqpTOE_kDnGh_ep3YzP9lvT1EXNZn149NKBZS6O7wb...       James Davis
# 1       gp:AOqpTOEsFX7k4uvzb9nMFhm3_F_fi8jO4XJRTDXaVTT...            Alex D
# 2       gp:AOqpTOFrbe5VHxNYs2DiAiQSBE1iRudXd0z1vB9U77T...    Emil Laukkanen
# 3       gp:AOqpTOFlSy_0E2l-R9A3ncMJF2RVTNgfk6i818PufiG...   Humphrey Little
# 4       gp:AOqpTOHc7vZRC2k4YEsHxfGNZsEWRieGIboc5CILynv...  Abdelhay Amazdar
# ...                                                   ...               ...
# 531169  gp:AOqpTOEBenCXdzF7WTqDqg93-CcQTbXd0Te-U09PVer...      Patrick Mick
# 531170  gp:AOqpTOEEOLY8L3njRfwp3aIcYCS5-opukZxFEfUU0aA...      Steven Evans
# 531171  gp:AOqpTOGWZIFa_iXckzfOuwOF9NsgovyWusXR3Xv53dh...     Curious Minds
# 531172  gp:AOqpTOF1xxymN4l9uyYNQroAS32cD4BSW7qxkpl5GLM...       Wesley Mory
# 531173  gp:AOqpTOHeyqpoqG7UuqvKxU6IB0k-IT6yTUSzXZuWD2O...      Karim Varela
#
# ...

# %%
# Adds sentiment columns | Credits to Stack Overflow
def sentiment_calc(text):
    try:
        return TextBlob(text).sentiment
    except:
        return None

df['sentiment'] = df['content'].apply(sentiment_calc)

# %%
# Adds polarity column | Credits to Stack Overflow
def polarity_calc(text):
    try:
        return TextBlob(text).polarity
    except:
        return None

df['polarity'] = df['content'].apply(polarity_calc)

# %%
# Adds subjectivity column | Credits to Stack Overflow
def subjectivity_calc(text):
    try:
        return TextBlob(text).subjectivity
    except:
        return None

df['subjectivity'] = df['content'].apply(subjectivity_calc)

# %%
df
# Out:
#                                                  reviewId          userName  \
# 0       gp:AOqpTOE_kDnGh_ep3YzP9lvT1EXNZn149NKBZS6O7wb...       James Davis
# 1       gp:AOqpTOEsFX7k4uvzb9nMFhm3_F_fi8jO4XJRTDXaVTT...            Alex D
# 2       gp:AOqpTOFrbe5VHxNYs2DiAiQSBE1iRudXd0z1vB9U77T...    Emil Laukkanen
# 3       gp:AOqpTOFlSy_0E2l-R9A3ncMJF2RVTNgfk6i818PufiG...   Humphrey Little
# 4       gp:AOqpTOHc7vZRC2k4YEsHxfGNZsEWRieGIboc5CILynv...  Abdelhay Amazdar
# ...                                                   ...               ...
# 531169  gp:AOqpTOEBenCXdzF7WTqDqg93-CcQTbXd0Te-U09PVer...      Patrick Mick
# 531170  gp:AOqpTOEEOLY8L3njRfwp3aIcYCS5-opukZxFEfUU0aA...      Steven Evans
# 531171  gp:AOqpTOGWZIFa_iXckzfOuwOF9NsgovyWusXR3Xv53dh...     Curious Minds
# 531172  gp:AOqpTOF1xxymN4l9uyYNQroAS32cD4BSW7qxkpl5GLM...       Wesley Mory
# 531173  gp:AOqpTOHeyqpoqG7UuqvKxU6IB0k-IT6yTUSzXZuWD2O...      Karim Varela
#
# ...

# %%
# Export final dataframe
df.to_csv("exports out final csv dataframe")
